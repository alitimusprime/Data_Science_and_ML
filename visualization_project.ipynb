# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cancer = pd.read_csv("cancer.csv")

# %%
data = cancer
data
# Out:
#      Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  \
# 0        0    5          1           1          1          2          1
# 1        0    5          4           4          5          7         10
# 2        0    3          1           1          1          2          2
# 3        0    6          8           8          1          3          4
# 4        0    4          1           1          3          2          1
# ..     ...  ...        ...         ...        ...        ...        ...
# 678      0    3          1           1          1          3          2
# 679      0    2          1           1          1          2          1
# 680      1    5         10          10          3          7          3
# 681      1    4          8           6          4          3          4
# 682      1    4          8           8          5          4          5
#
#      breast  breast-quad  irradiat
# 0         3            1         1
# ...

# %%
data.columns
# Out:
# Index(['Class', 'age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps',
#        'deg-malig', 'breast', 'breast-quad', 'irradiat'],
#       dtype='object')

# %%
data['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['Class'] = data['Class'].map({0: 'Benign', 1: 'Malignant'})

# %%
data["Class"]
# Out:
# 0         Benign
# 1         Benign
# 2         Benign
# 3         Benign
# 4         Benign
#          ...
# 678       Benign
# 679       Benign
# 680    Malignant
# 681    Malignant
# 682    Malignant
# Name: Class, Length: 683, dtype: object

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['menopause'], alpha=0.5, label=i)

plt.title('cancer through menopause')
plt.xlabel('menopause')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['tumor-size'], alpha=0.5, label=i)

plt.title('cancer through tumor-size')
plt.xlabel('tumor-size')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['inv-nodes'], alpha=0.5, label=i)

plt.title('cancer through inv-nodes')
plt.xlabel('inv-nodes')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['node-caps'], alpha=0.5, label=i)

plt.title('cancer through node-caps')
plt.xlabel('node-caps')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['deg-malig'], alpha=0.5, label=i)

plt.title('cancer through deg-malig')
plt.xlabel('deg-malig')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['breast'], alpha=0.5, label=i)

plt.title('cancer through breast')
plt.xlabel('breast')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['breast-quad'], alpha=0.5, label=i)

plt.title('cancer through breast-quad')
plt.xlabel('breast-quad')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the distribution of sepal length for each species
plt.figure(figsize=(10, 6))
for i in data['Class'].unique():
    subset = data[data['Class'] == i]
    plt.hist(subset['irradiat'], alpha=0.5, label=i)

plt.title('cancer through irradiat')
plt.xlabel('irradiat')
plt.ylabel('class')
plt.legend()
plt.grid(True)
plt.show()

# %%
#fig, axes = plt.subplots(ncols=len(data.columns), figsize=(20,5))
#for col, ax in zip(data, axes):
 #   data[col].value_counts().sort_index().plot.bar(ax=ax, title=col)

#plt.tight_layout()    
#plt.show()

# %%
#for col in data.columns:
    #plt.hist(data[col])
    #plt.xlabel(col)
    #plt.show()
