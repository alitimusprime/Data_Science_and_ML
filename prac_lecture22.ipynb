# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
csvfile = pd.read_csv('D4_Fish_Market_Dataset.csv')
csvfile
# Out:
#       ID Species  Weight  Length1  Length2  Length3   Height   Width
# 0      1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1      2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2      3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3      4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4      5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..   ...     ...     ...      ...      ...      ...      ...     ...
# 154  155   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155  156   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156  157   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157  158   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158  159   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 8 columns]

# %%
fish_data = csvfile

# %%
fish_data
# Out:
#       ID Species  Weight  Length1  Length2  Length3   Height   Width
# 0      1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1      2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2      3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3      4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4      5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..   ...     ...     ...      ...      ...      ...      ...     ...
# 154  155   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155  156   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156  157   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157  158   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158  159   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 8 columns]

# %%
fishdata_df = pd.DataFrame(fish_data)

# %%
fishdata_df
# Out:
#       ID Species  Weight  Length1  Length2  Length3   Height   Width
# 0      1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1      2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2      3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3      4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4      5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..   ...     ...     ...      ...      ...      ...      ...     ...
# 154  155   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155  156   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156  157   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157  158   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158  159   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 8 columns]

# %%
fishdata_df.head(10)
# Out:
#    ID Species  Weight  Length1  Length2  Length3   Height   Width
# 0   1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# 5   6   Bream   450.0     26.8     29.7     34.7  13.6024  4.9274
# 6   7   Bream   500.0     26.8     29.7     34.5  14.1795  5.2785
# 7   8   Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 8   9   Bream   450.0     27.6     30.0     35.1  14.0049  4.8438
# 9  10   Bream   500.0     28.5     30.7     36.2  14.2266  4.9594

# %%
fishdata_df.tail(10)
# Out:
#       ID Species  Weight  Length1  Length2  Length3  Height   Width
# 149  150   Smelt     9.8     10.7     11.2     12.4  2.0832  1.2772
# 150  151   Smelt     8.7     10.8     11.3     12.6  1.9782  1.2852
# 151  152   Smelt    10.0     11.3     11.8     13.1  2.2139  1.2838
# 152  153   Smelt     9.9     11.3     11.8     13.1  2.2139  1.1659
# 153  154   Smelt     9.8     11.4     12.0     13.2  2.2044  1.1484
# 154  155   Smelt    12.2     11.5     12.2     13.4  2.0904  1.3936
# 155  156   Smelt    13.4     11.7     12.4     13.5  2.4300  1.2690
# 156  157   Smelt    12.2     12.1     13.0     13.8  2.2770  1.2558
# 157  158   Smelt    19.7     13.2     14.3     15.2  2.8728  2.0672
# 158  159   Smelt    19.9     13.8     15.0     16.2  2.9322  1.8792

# %%
#number of rows
len(fishdata_df)
# Out:
# 159

# %%
#number of columns
len(fishdata_df.columns)
# Out:
# 8

# %%
#finding data type
type(fishdata_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#finding data type

fishdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       159 non-null    int64
#  1   Species  159 non-null    object
#  2   Weight   159 non-null    float64
#  3   Length1  159 non-null    float64
#  4   Length2  159 non-null    float64
#  5   Length3  159 non-null    float64
#  6   Height   159 non-null    float64
#  7   Width    159 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 10.1+ KB

# %%
#way to find rows and columns
fishdata_df.shape
# Out:
# (159, 8)

# %%
print(fishdata_df)
# Out:
#       ID Species  Weight  Length1  Length2  Length3   Height   Width
# 0      1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1      2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2      3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3      4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4      5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..   ...     ...     ...      ...      ...      ...      ...     ...
# 154  155   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155  156   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156  157   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157  158   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158  159   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 8 columns]

# %%
fishdata_df['Species'].value_counts()
# Out:
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: count, dtype: int64

# %%
fishdata_df['Sum'] = fishdata_df['Length1'] + fishdata_df['Length2'] + fishdata_df['Length3'] 
fishdata_df
# Out:
#       ID Species  Weight  Length1  Length2  Length3   Height   Width   Sum
# 0      1   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200  78.6
# 1      2   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056  81.5
# 2      3   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961  81.5
# 3      4   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555  88.8
# 4      5   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340  89.5
# ..   ...     ...     ...      ...      ...      ...      ...     ...   ...
# 154  155   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936  37.1
# 155  156   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690  37.6
# 156  157   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558  38.9
# 157  158   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672  42.7
# 158  159   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792  45.0
#
# [159 rows x 9 columns]

# %%
x = fishdata_df['Sum']
y = fishdata_df['Height']
plt.figure(figsize= (10,5))
plt.scatter(x, y, color='green', marker='o')
plt.plot()
plt.title("Graph for Sum", color = "Black" )
plt.xlabel("Sum")
plt.ylabel("Species")
plt.grid(True)
plt.show()

# %%
# finding null values but without .sum() we get only a few values not all of them so we use sum function to check the sum of the null values in all
# columns so if it is zero then it means that it has no value that is null.
fishdata_df.isnull().sum()
# Out:
# ID         0
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# Sum        0
# dtype: int64
