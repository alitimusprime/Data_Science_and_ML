# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('qEHqag.csv')

# %%
data = movies

# %%
data
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
data.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
data['Released_Year']
# Out:
# 0      1994
# 1      1972
# 2      2008
# 3      1974
# 4      1957
#        ...
# 995    1961
# 996    1956
# 997    1953
# 998    1944
# 999    1935
# Name: Released_Year, Length: 1000, dtype: object

# %%
data[data["Released_Year"] == '2001']
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 23                       Sen to Chihiro no kamikakushi          2001      125
# 95                                              Amélie          2001      122
# 159                                   A Beautiful Mind          2001      135
# 240                                     Dil Chahta Hai          2001      183
# 245                                     Monsters, Inc.          2001       92
# 247                  Lagaan: Once Upon a Time in India          2001      224
# 379                               Yeopgijeogin geunyeo          2001      137
# 381                                          Vizontele          2001      110
# 382                                       Donnie Darko          2001      113
# 509                                      No Man's Land          2001       98
# ...

# %%
xd = data[data["Released_Year"] == '2014']
xd[xd["Genre"] == 'Action'] 
# iss tarah kar sakte hain ham access 2 columns ko access
# yahan pe release year aur genre dono ko aik saath kara hai
# iska masla ye hai ke ham baar baar variables nhi bana sakte kiun ke woh memory consume karta hai zyada
# Out:
#                             Series_Title Released_Year  Runtime   Genre  \
# 201                               Haider          2014      160  Action
# 337             Serbuan maut 2: Berandal          2014      150  Action
# 339              Guardians of the Galaxy          2014      121  Action
# 479           X-Men: Days of Future Past          2014      132  Action
# 482                     Edge of Tomorrow          2014      113  Action
# 730         Kingsman: The Secret Service          2014      129  Action
# 737  Captain America: The Winter Soldier          2014      136  Action
# 898       Dawn of the Planet of the Apes          2014      130  Action
#
#      IMDB_Rating         Director            Star1  No_of_Votes        Gross  \
# 201          8.1  Vishal Bhardwaj    Shahid Kapoor        50445     901610.0
# 337          8.0     Gareth Evans        Iko Uwais       114316    2625803.0
# 339          8.0       James Gunn      Chris Pratt      1043455  333176600.0
# ...

# %%
data[data['Released_Year'] == '2014'][data[data['Released_Year'] == '2014']['Director'] == 'Don Hall']
# ye zyada efficient tareeqa hai 2 columns ko access karne ka
# Out:
#     Series_Title Released_Year  Runtime      Genre  IMDB_Rating  Director  \
# 592   Big Hero 6          2014      102  Animation          7.8  Don Hall
#
#               Star1  No_of_Votes        Gross  Metascore
# 592  Chris Williams       410983  222527828.0       74.0
